# %%
b = 3.00
d = 6.00
tahmin = e
hedef = 12.0
def loss(hedef, tahmin):
  return (hedef - tahmin)**2
a_listesi = []
loss_listesi = []
for i in range(13):
    a = 0.0 + i*0.5
    c = a * b
    e = c + d
    print(a, loss(hedef, e))
    a_listesi.append(a)
    loss_listesi.append(loss(hedef, e))


import matplotlib.pyplot as plt
plt.plot(a_listesi, loss_listesi)
# Out:
# 0.0 36.0
# 0.5 20.25
# 1.0 9.0
# 1.5 2.25
# 2.0 0.0
# 2.5 2.25
# 3.0 9.0
# 3.5 20.25
# 4.0 36.0
# 4.5 56.25
# 5.0 81.0
# 5.5 110.25
# 6.0 144.0
